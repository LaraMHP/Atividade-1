# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraMHP/Atividade-1/blob/main/Aitividade1_VC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Para fazer o upload de uma imagem
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-826dbd08-282d-4fbf-9a60-f92d891202bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-826dbd08-282d-4fbf-9a60-f92d891202bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Desafio 1-2

# %%
import cv2
import matplotlib.pyplot as plt

# Carregar a imagem
imagem = cv2.imread("Imagem_VC.jpg")

# Converter de BGR para RGB para exibir corretamente
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# Coordenadas do pixel [0,0]
x, y = 0, 0

# Desenhar um círculo no pixel [0,0] para destacá-lo
marcada = imagem_rgb.copy()
cv2.circle(marcada, (x, y), radius=10, color=(255, 0, 0), thickness=-1)  # Azul puro

# Mostrar imagem original e marcada lado a lado
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Imagem Original")
plt.imshow(imagem_rgb)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Pixel [0,0] marcado")
plt.imshow(marcada)
plt.axis("off")

plt.show()

# %% [markdown]
# Desafio 1-3

# %%
import cv2

imagem = cv2.imread("Imagem_VC.jpg")
altura, largura, canais = imagem.shape

cantos = {
    "Superior esquerdo": (0, 0),
    "Superior direito": (0, largura-1),
    "Inferior esquerdo": (altura-1, 0),
    "Inferior direito": (altura-1, largura-1)
}

for nome, (y, x) in cantos.items():
    (b, g, r) = imagem[y, x]
    print(f"{nome} -> Vermelho: {r}, Verde: {g}, Azul: {b}")
# Out:
# Superior esquerdo -> Vermelho: 96, Verde: 80, Azul: 81
# Superior direito -> Vermelho: 253, Verde: 192, Azul: 165
# Inferior esquerdo -> Vermelho: 3, Verde: 5, Azul: 4
# Inferior direito -> Vermelho: 73, Verde: 70, Azul: 65

# %% [markdown]
# Desafio 1-4

# %%
import numpy as np

media_b = np.mean(imagem[:, :, 0])
media_g = np.mean(imagem[:, :, 1])
media_r = np.mean(imagem[:, :, 2])

print(f"Cor média -> Vermelho: {media_r:.2f}, Verde: {media_g:.2f}, Azul: {media_b:.2f}")
# Out:
# Cor média -> Vermelho: 102.75, Verde: 58.82, Azul: 48.37

# %% [markdown]
# Desafio 1-5

# %%
if media_r > media_g and media_r > media_b:
    print("A imagem tem predominância de VERMELHO.")
elif media_g > media_r and media_g > media_b:
    print("A imagem tem predominância de VERDE.")
else:
    print("A imagem tem predominância de AZUL.")
# Out:
# A imagem tem predominância de VERMELHO.

# %% [markdown]
# Desafio 2

# %%
import cv2
from matplotlib import pyplot as plt

# 1) Ler a imagem
imagem = cv2.imread("Imagem_VC.jpg")

# 2) Alterar um pixel específico
imagem[100, 100] = (0, 255, 0)  # Verde puro em (100,100)

# 3) Salvar a imagem modificada
cv2.imwrite("Imagem_VC_modificada.jpg", imagem)

# 4) Exibir imagens lado a lado
original = cv2.imread("Imagem_VC.jpg")
modificada = cv2.imread("Imagem_VC_modificada.jpg")

# Converter para RGB para exibição correta
original = cv2.cvtColor(original, cv2.COLOR_BGR2RGB)
modificada = cv2.cvtColor(modificada, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.title("Imagem Original")
plt.imshow(original)
plt.axis("off")

plt.subplot(1,2,2)
plt.title("Imagem Modificada")
plt.imshow(modificada)
plt.axis("off")

plt.show()
